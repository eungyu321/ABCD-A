# %% [markdown]
# <a href="https://colab.research.google.com/github/eungyu321/ABCD-A/blob/20250310/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
print('hello','everyone')
print('hello'+'everyone')

print('hello',end='')
print('test')

a=123
b='hello'
print(a,b)
print(a,456,b,'world')

print('hello "python"')
print("hello 'python'")
print('hello','python!')
print('hello' + 'python!')

print("화면에 직접 출력")
print('ab\'c')
print("ab'c")
print("dosen't")
print('does')
print('doesn\'t')
print("'string'")
print("\"string\"")
print('"string"')

s1='화면에 직접 출력'
s2='ab\'c'
s3='does'
print(s1)
print(s2)
print(s3)
print(s1[0])#첫 글자
print(s2[1])#두 번째 글자
print(s3[1:3])
print(s3[-1])#마지막 글자
print(s3[-2])#뒤에서 두 번째

a=2
b=3.1452
c=a+b
print(a)
print(b)
print(c)
print(round(c,2))
print("%.2f" %(c))
print(a+b)
print(a,b,a+b,c)
d=1e2
e=1e-2
print(d)
print(e)

item1='사과'
price1=1000
item2='바나나'
price2=500
print(item1,price1)
print(item2,price2)

print(' ')
print(' ')
print(' ')
print(' ')

str1='{0}는 {1}원입니다.'
print(str1.format(item1,price1))
print(str1.format(item2,price2))

print(item1,price1,sep='*', end='/')
print(item2,price2)

print(' ')
print(' ')
print(' ')
print(' ')

str2='%s는 %d원입니다.'
print(str2%(item1, price1))
print(str2%(item2, price2))
# Out:
# hello
# hello everyone
# helloeveryone
# hellotest
# 123 hello
# 123 456 hello world
# hello "python"
# hello 'python'
# hello python!
# hellopython!
# 화면에 직접 출력
# ab'c
# ab'c
# dosen't
# does
# doesn't
# 'string'
# "string"
# "string"
# 화면에 직접 출력
# ab'c
# does
# 화
# b
# oe
# s
# e
# 2
# 3.1452
# 5.1452
# 5.15
# 5.15
# 5.1452
# 2 3.1452 5.1452 5.1452
# 100.0
# 0.01
# 사과 1000
# 바나나 500
#
#
#
#
# 사과는 1000원입니다.
# 바나나는 500원입니다.
# 사과*1000/바나나 500
#
#
#
#
# 사과는 1000원입니다.
# 바나나는 500원입니다.
