# %%
pip install ultralytics opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import zipfile

zip_path = r"ABCD-A ---- ----.v2i.yolov8.zip"
extract_to = r"C:\Users\halla\Desktop\image\halla1"  # ✅ 압축을 풀 대상 폴더

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_to)

# %%
#학습
from ultralytics import YOLO
model = YOLO('yolov8n-seg.pt')  # 또는 yolov8s-seg.pt 등
model.train(
   data = r""C:\Users\halla\Desktop\qqq\---- abcd-a -- --.v1i.yolov8.zip""  # 절대 경로
, #yaml 수정
    epochs=2000, #횟수
    imgsz=640,
    task='segment',
    workers=0,
    patience=0
)
# Out:
# Ultralytics 8.3.146  Python-3.10.16 torch-2.1.2+cu118 CUDA:0 (NVIDIA GeForce RTX 3070, 8192MiB)
# ...

# %%
# YOLO 예측 결과 이미지 저장
import os
from glob import glob
from ultralytics import YOLO
import cv2

# ✅ 학습된 모델 경로 (.pt)
model_path = r"C:\Users\halla\Desktop\image\runs"
model = YOLO(model_path)

# ✅ 예측할 이미지 폴더 (원본 이미지들이 있는 경로)
input_folder = r"C:\Users\halla\Downloads\---- abcd-a -- --.v1i.yolov8.zip"

# ✅ 예측 결과 저장할 폴더
output_folder = r"C:\Users\halla\Desktop\qqq"
os.makedirs(output_folder, exist_ok=True)

# ✅ 이미지 파일 목록 불러오기
image_paths = sorted(glob(os.path.join(input_folder, '*.jpg')) + glob(os.path.join(input_folder, '*.png')))

# ✅ 이미지별 예측하고 저장
for img_path in image_paths:
    results = model(img_path)  # 예측
    labeled_img = results[0].plot()  # 시각화
    filename = os.path.basename(img_path)
    save_path = os.path.join(output_folder, filename)
    cv2.imwrite(save_path, labeled_img)

print(f"✅ 총 {len(image_paths)}장의 예측 이미지 저장 완료: {output_folder}")
# Out:
# WARNING Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# ✅ 총 0장의 예측 이미지 저장 완료: C:\Users\halla\Desktop\qqq

# %%
# YOLO 예측 결과 이미지들을 영상으로 변환
import cv2
import os
from glob import glob

# ✅ 위에서 저장한 예측 이미지 폴더
img_folder = r"C:\Users\halla\Desktop\image\yolo_outputs"

# ✅ 저장할 영상 경로
output_video = r"C:\Users\halla\Desktop\image\yolo_output_video.mp4"


# ✅ 이미지 파일 목록 불러오기
img_files = sorted(glob(os.path.join(img_folder, '*.jpg')) + glob(os.path.join(img_folder, '*.png')))
if not img_files:
    print(f"❌ 이미지가 없습니다: {img_folder}")
else:
    # 첫 이미지로 사이즈 설정
    frame = cv2.imread(img_files[0])
    height, width, _ = frame.shape

    # 영상 설정 (FPS 5)
    video = cv2.VideoWriter(output_video, cv2.VideoWriter_fourcc(*'mp4v'), 5, (width, height))

    for img_path in img_files:
        frame = cv2.imread(img_path)
        video.write(frame)

    video.release()
    print(f"✅ 비디오 저장 완료: {output_video}")
# Out:
# ✅ 비디오 저장 완료: C:\Users\halla\Desktop\image\yolo_output_video.mp4
